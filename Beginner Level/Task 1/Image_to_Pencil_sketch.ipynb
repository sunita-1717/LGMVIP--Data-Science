# %% [markdown]
# <a href="https://colab.research.google.com/github/sunita-1717/LGMVIP--Data-Science/blob/main/Beginner%20Level/Task%201/Image_to_Pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LetsGrowMore (LGMVIP) - "DATA SCIENCE INTERN"
# **AUTHOR - SUNITA KURANE.**
#
# **BEGINNER LEVEL TASK**
#
# **TASK 1- Image to Pencil Sketch with Python**
#
# ---

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Reading The Input Image

# %%
img = cv2.imread("/content/dog.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(img)
plt.show()

# %% [markdown]
# # Converting image into gray scale image

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.axis('off')
plt.imshow(gray_img)
plt.show()

# %% [markdown]
# # Inverting the Gray Image

# %%
inv_gray_img = cv2.bitwise_not(gray_img)
plt.axis('off')
plt.imshow(inv_gray_img)
plt.show()

# %% [markdown]
# # Blurring the inverted gray image by Gausian Function

# %%
blur_img = cv2.GaussianBlur(inv_gray_img,(21,21),0)
plt.axis('off')
plt.imshow(blur_img)
plt.show()

# %% [markdown]
# # Inverting the blurred image

# %%
inv_blur_img = cv2.bitwise_not(blur_img)
plt.axis('off')
plt.imshow(inv_blur_img)
plt.show()

# %% [markdown]
# # Creating Pencil Sketch image

# %%
pencil_img = cv2.divide(gray_img,inv_blur_img,scale = 256.0)
plt.axis('off')
plt.imshow(pencil_img)
plt.show()

# %%
cv2.imwrite("./output_dog.png",pencil_img)
# Out:
# True
